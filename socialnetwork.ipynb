# %%
import os
import networkx as nx
from community import community_louvain
from networkx.algorithms.community import girvan_newman
from sklearn.metrics import normalized_mutual_info_score, f1_score
import itertools

# %%
def load_facebook_ego_graph(base_dir, node_id):
    edges_file = os.path.join(base_dir, f"{node_id}.edges")
    circles_file = os.path.join(base_dir, f"{node_id}.circles")

    G = nx.Graph()
    with open(edges_file, 'r') as ef:
        for line in ef:
            u, v = line.strip().split()
            G.add_edge(u, v)

    ground_truth_communities = []
    if os.path.exists(circles_file):
        with open(circles_file, 'r') as cf:
            for line in cf:
                parts = line.strip().split()
                members = parts[1:]
                members_in_graph = [m for m in members if m in G.nodes()]
                if len(members_in_graph) > 0:
                    ground_truth_communities.append(set(members_in_graph))
    else:
        ground_truth_communities = []

    return G, ground_truth_communities

# %%
def detect_communities_louvain(G):
    partition = community_louvain.best_partition(G)
    communities = {}
    for node, com_id in partition.items():
        communities.setdefault(com_id, []).append(node)
    return [set(c) for c in communities.values()]

def detect_communities_girvan_newman(G, top_level=1):
    comp = girvan_newman(G)
    for level in range(top_level):
        communities = next(comp)
    return [set(c) for c in communities]

def f1_for_sets(true_set, pred_set):
    inter = len(true_set.intersection(pred_set))
    precision = inter / len(pred_set) if len(pred_set) > 0 else 0.0
    recall = inter / len(true_set) if len(true_set) > 0 else 0.0
    if (precision + recall) > 0:
        return 2 * (precision * recall) / (precision + recall)
    else:
        return 0.0

# %%
def detect_communities_louvain(G):
    partition = community_louvain.best_partition(G)
    communities = {}
    for node, com_id in partition.items():
        communities.setdefault(com_id, []).append(node)
    return [set(c) for c in communities.values()]

def detect_communities_girvan_newman(G, top_level=1):
    comp = girvan_newman(G)
    for level in range(top_level):
        communities = next(comp)
    return [set(c) for c in communities]

# %%
def evaluate_communities(detected_communities, ground_truth_communities):
    if not ground_truth_communities:
        return 0.0, 0.0

    all_nodes = set().union(*ground_truth_communities).union(*detected_communities)
    all_nodes = list(all_nodes)
    node_index = {n: i for i,n in enumerate(all_nodes)}

    def communities_to_labels(communities):
        labels = [-1]*len(all_nodes)
        max_cid = 0
        for cid, com in enumerate(communities):
            for node in com:
                if labels[node_index[node]] == -1:
                    labels[node_index[node]] = cid
                    if cid > max_cid:
                        max_cid = cid
        for i, l in enumerate(labels):
            if l == -1:
                max_cid += 1
                labels[i] = max_cid
        return labels

    gt_labels = communities_to_labels(ground_truth_communities)
    det_labels = communities_to_labels(detected_communities)
    nmi = normalized_mutual_info_score(gt_labels, det_labels)

    f1_scores = []
    for gt_com in ground_truth_communities:
        best_f1 = 0.0
        for dt_com in detected_communities:
            score = f1_for_sets(gt_com, dt_com)
            if score > best_f1:
                best_f1 = score
        f1_scores.append(best_f1)
    avg_f1 = sum(f1_scores)/len(f1_scores) if f1_scores else 0.0

    return nmi, avg_f1

# %%
if __name__ == "__main__":
    base_dir = "facebook"
    node_ids = ["0","107","348","414","686","698","1684","1912","3437","3980"]

    print("node_id\tLouvain_NMI\tLouvain_F1\tGN_NMI\tGN_F1")
    for nid in node_ids:
        G, ground_truth = load_facebook_ego_graph(base_dir, nid)

        louvain_coms = detect_communities_louvain(G)
        louvain_nmi, louvain_f1 = evaluate_communities(louvain_coms, ground_truth)

        gn_coms = detect_communities_girvan_newman(G, top_level=1)
        gn_nmi, gn_f1 = evaluate_communities(gn_coms, ground_truth)

        print(f"{nid}\t{louvain_nmi:.4f}\t{louvain_f1:.4f}\t{gn_nmi:.4f}\t{gn_f1:.4f}")
# Out:
# node_id	Louvain_NMI	Louvain_F1	GN_NMI	GN_F1
# 0	0.4341	0.2595	0.2688	0.1988
# 107	0.4368	0.3274	0.0149	0.0917
# 348	0.2702	0.4672	0.2869	0.3276
# 414	0.6581	0.5362	0.3957	0.3912
# 686	0.4667	0.4630	0.0236	0.3243
# 698	0.7003	0.5110	0.5440	0.3884
# 1684	0.6786	0.4060	0.1471	0.2000
# 1912	0.4940	0.1852	0.0414	0.0998
# 3437	0.5087	0.1111	0.0560	0.0306
# 3980	0.6874	0.4587	0.4384	0.3295

# %%
import os
import networkx as nx
from community import community_louvain
from networkx.algorithms.community import girvan_newman
from sklearn.metrics import normalized_mutual_info_score
import statistics

def load_facebook_ego_graph(base_dir, node_id):
    edges_file = os.path.join(base_dir, f"{node_id}.edges")
    circles_file = os.path.join(base_dir, f"{node_id}.circles")

    G = nx.Graph()
    with open(edges_file, 'r') as ef:
        for line in ef:
            u, v = line.strip().split()
            G.add_edge(u, v)

    ground_truth_communities = []
    if os.path.exists(circles_file):
        with open(circles_file, 'r') as cf:
            for line in cf:
                parts = line.strip().split()
                members = parts[1:]
                members_in_graph = [m for m in members if m in G.nodes()]
                if len(members_in_graph) > 0:
                    ground_truth_communities.append(set(members_in_graph))
    else:
        ground_truth_communities = []

    return G, ground_truth_communities

def detect_communities_louvain(G):
    partition = community_louvain.best_partition(G)
    communities = {}
    for node, com_id in partition.items():
        communities.setdefault(com_id, []).append(node)
    return [set(c) for c in communities.values()]

def detect_communities_girvan_newman(G, top_level=1):
    comp = girvan_newman(G)
    for level in range(top_level):
        communities = next(comp)
    return [set(c) for c in communities]

def f1_for_sets(true_set, pred_set):
    inter = len(true_set.intersection(pred_set))
    precision = inter / len(pred_set) if len(pred_set) > 0 else 0.0
    recall = inter / len(true_set) if len(true_set) > 0 else 0.0
    if (precision + recall) > 0:
        return 2 * (precision * recall) / (precision + recall)
    else:
        return 0.0

def evaluate_communities(detected_communities, ground_truth_communities):
    if not ground_truth_communities:
        return 0.0, 0.0
    all_nodes = set().union(*ground_truth_communities).union(*detected_communities)
    all_nodes = list(all_nodes)
    node_index = {n: i for i,n in enumerate(all_nodes)}

    def communities_to_labels(communities):
        labels = [-1]*len(all_nodes)
        max_cid = 0
        for cid, com in enumerate(communities):
            for node in com:
                if labels[node_index[node]] == -1:
                    labels[node_index[node]] = cid
                    if cid > max_cid:
                        max_cid = cid
        for i, l in enumerate(labels):
            if l == -1:
                max_cid += 1
                labels[i] = max_cid
        return labels

    gt_labels = communities_to_labels(ground_truth_communities)
    det_labels = communities_to_labels(detected_communities)
    nmi = normalized_mutual_info_score(gt_labels, det_labels)

    # 计算F1
    f1_scores = []
    for gt_com in ground_truth_communities:
        best_f1 = 0.0
        for dt_com in detected_communities:
            score = f1_for_sets(gt_com, dt_com)
            if score > best_f1:
                best_f1 = score
        f1_scores.append(best_f1)
    avg_f1 = sum(f1_scores)/len(f1_scores) if f1_scores else 0.0

    return nmi, avg_f1



def compute_mS_cS(G, S):

    S = set(S)
    mS = 0
    cS = 0
    for u in S:
        for v in G[u]:
            if v in S:
                if u < v:
                    mS += 1
            else:
                cS += 1
    return mS, cS

def compute_scoring_functions(G, communities):
    """

    nS = |S|
    mS = #edges inside S
    cS = #edges leaving S
    d(u) = degree of node u
    """
    n = G.number_of_nodes()
    m = G.number_of_edges()

    degrees = {node: G.degree(node) for node in G.nodes()}
    all_degs = sorted(degrees.values())
    dm = statistics.median(all_degs) if all_degs else 0.0

    results = []
    for S in communities:
        nS = len(S)
        if nS <= 1:

            results.append({"Internal density":0,"Edges inside":0,"Average degree":0,"FOMD":0,"TPR":0,
                            "Expansion":0,"Cut Ratio":0,"Conductance":0,"Normalized Cut":0,"Max-ODF":0,
                            "Avg-ODF":0,"Flake-ODF":0,"Modularity":0})
            continue
        mS, cS = compute_mS_cS(G, S)


        if nS*(nS-1)/2 > 0:
            internal_density = mS/(nS*(nS-1)/2)
        else:
            internal_density = 0

        edges_inside = mS

        avg_degree = (2*mS/nS) if nS>0 else 0

        internal_degs = []
        for u in S:
            internal_deg_u = len([v for v in G[u] if v in S])
            internal_degs.append(internal_deg_u)
        count_over_dm = sum(1 for d_iu in internal_degs if d_iu > dm)
        FOMD = count_over_dm/nS

        triad_count = 0
        S_subgraph = G.subgraph(S)
        for u in S:
            neighbors_in_S = [x for x in G[u] if x in S]
            found_triangle = False
            for i in range(len(neighbors_in_S)):
                for j in range(i+1, len(neighbors_in_S)):
                    v = neighbors_in_S[i]
                    w = neighbors_in_S[j]
                    if S_subgraph.has_edge(v,w):
                        found_triangle = True
                        break
                if found_triangle:
                    break
            if found_triangle:
                triad_count += 1
        TPR = triad_count/nS

        expansion = cS/nS if nS>0 else 0

        if nS*(n-nS) > 0:
            cut_ratio = cS/(nS*(n-nS))
        else:
            cut_ratio = 0

        if (2*mS+cS) > 0:
            conductance = cS/(2*mS+cS)
        else:
            conductance = 0

        denom_2 = 2*(m - mS)+ cS
        if denom_2 > 0:
            normalized_cut = conductance + cS/denom_2
        else:
            normalized_cut = conductance

        max_odf = 0
        avg_odf_vals = []
        flake_odf_count = 0
        for u in S:
            deg_u = degrees[u]
            internal_deg_u = len([v for v in G[u] if v in S])
            external_deg_u = deg_u - internal_deg_u
            if deg_u > 0:
                out_frac = external_deg_u/deg_u
            else:
                out_frac = 0
            avg_odf_vals.append(out_frac)
            if out_frac > max_odf:
                max_odf = out_frac
            if internal_deg_u < deg_u/2:
                flake_odf_count += 1

        # Average-ODF
        avg_odf = sum(avg_odf_vals)/len(avg_odf_vals) if avg_odf_vals else 0
        # Flake-ODF = fraction of nodes with fewer than half their edges inside
        flake_odf = flake_odf_count/nS

        # Modularity: f(S) = (mS - E(mS)) / (4),:
        # Modularity = (mS/ m) - (sum(deg(u) for u in S)^2)/(4*m^2)
        sum_deg_S = sum(degrees[u] for u in S)
        expected_mS = (sum_deg_S**2)/(4*m) if m>0 else 0
        modularity = (mS - expected_mS)/4

        res = {
            "Internal density": internal_density,
            "Edges inside": edges_inside,
            "Average degree": avg_degree,
            "FOMD": FOMD,
            "TPR": TPR,
            "Expansion": expansion,
            "Cut Ratio": cut_ratio,
            "Conductance": conductance,
            "Normalized Cut": normalized_cut,
            "Max-ODF": max_odf,
            "Avg-ODF": avg_odf,
            "Flake-ODF": flake_odf,
            "Modularity": modularity
        }
        results.append(res)
    return results

if __name__ == "__main__":
    base_dir = "facebook"
    node_ids = ["0","107","348","414","686","698","1684","1912","3437","3980"]

    print("node_id\tLouvain_NMI\tLouvain_F1\tGN_NMI\tGN_F1")
    for nid in node_ids:
        G, ground_truth = load_facebook_ego_graph(base_dir, nid)
        louvain_coms = detect_communities_louvain(G)
        louvain_nmi, louvain_f1 = evaluate_communities(louvain_coms, ground_truth)

        gn_coms = detect_communities_girvan_newman(G, top_level=1)
        gn_nmi, gn_f1 = evaluate_communities(gn_coms, ground_truth)

        print(f"{nid}\t{louvain_nmi:.4f}\t{louvain_f1:.4f}\t{gn_nmi:.4f}\t{gn_f1:.4f}")

        louvain_scores = compute_scoring_functions(G, louvain_coms)
        print(f"Louvain communities scoring for node_id={nid}:")
        for i, score_dict in enumerate(louvain_scores):
            print(f" Community {i}:")
            for k,v in score_dict.items():
                print(f"   {k}: {v:.4f}")

        gn_scores = compute_scoring_functions(G, gn_coms)
        print(f"Girvan-Newman communities scoring for node_id={nid}:")
        for i, score_dict in enumerate(gn_scores):
            print(f" Community {i}:")
            for k,v in score_dict.items():
                print(f"   {k}: {v:.4f}")
# Out:
# node_id	Louvain_NMI	Louvain_F1	GN_NMI	GN_F1
# 0	0.4359	0.2652	0.2688	0.1988
# Louvain communities scoring for node_id=0:
#  Community 0:
#    Internal density: 0.2316
#    Edges inside: 907.0000
#    Average degree: 20.3820
#    FOMD: 0.6966
#    TPR: 0.9551
#    Expansion: 6.3146
#    Cut Ratio: 0.0259
#    Conductance: 0.2365
#    Normalized Cut: 0.3850
#    Max-ODF: 0.4182
#    Avg-ODF: 0.1860
#    Flake-ODF: 0.0000
#    Modularity: 86.6801
#  Community 1:
#    Internal density: 0.3883
#    Edges inside: 205.0000
#    Average degree: 12.4242
#    FOMD: 0.5758
#    TPR: 0.9091
#    Expansion: 2.7273
#    Cut Ratio: 0.0091
#    Conductance: 0.1800
#    Normalized Cut: 0.1991
#    Max-ODF: 0.6667
#    Avg-ODF: 0.2056
#    Flake-ODF: 0.0606
#    Modularity: 45.0471
#  Community 2:
#    Internal density: 0.1595
#    Edges inside: 56.0000
#    Average degree: 4.1481
#    FOMD: 0.0370
#    TPR: 0.6667
#    Expansion: 3.8148
#    Cut Ratio: 0.0125
#    Conductance: 0.4791
#    Normalized Cut: 0.4996
#    Max-ODF: 0.7705
#    Avg-ODF: 0.2007
#    Flake-ODF: 0.2593
#    Modularity: 12.8531
#  Community 3:
#    Internal density: 0.2033
#    Edges inside: 61.0000
#    Average degree: 4.8800
#    FOMD: 0.0800
#    TPR: 0.6400
#    Expansion: 6.3200
#    Cut Ratio: 0.0205
#    Conductance: 0.5643
#    Normalized Cut: 0.5954
#    Max-ODF: 0.8158
#    Avg-ODF: 0.4777
#    Flake-ODF: 0.4000
#    Modularity: 13.3048
#  Community 4:
#    Internal density: 0.3730
#    Edges inside: 185.0000
#    Average degree: 11.5625
#    FOMD: 0.5000
#    TPR: 0.9375
#    Expansion: 11.4688
#    Cut Ratio: 0.0381
#    Conductance: 0.4980
#    Normalized Cut: 0.5709
#    Max-ODF: 0.7500
#    Avg-ODF: 0.4698
#    Flake-ODF: 0.3750
#    Modularity: 32.7732
#  Community 5:
#    Internal density: 0.1664
#    Edges inside: 99.0000
#    Average degree: 5.6571
#    FOMD: 0.1429
#    TPR: 0.8000
#    Expansion: 0.6857
#    Cut Ratio: 0.0023
#    Conductance: 0.1081
#    Normalized Cut: 0.1130
#    Max-ODF: 0.7500
#    Avg-ODF: 0.0866
#    Flake-ODF: 0.0286
#    Modularity: 23.5272
#  Community 6:
#    Internal density: 0.8718
#    Edges inside: 68.0000
#    Average degree: 10.4615
#    FOMD: 0.5385
#    TPR: 1.0000
#    Expansion: 2.6923
#    Cut Ratio: 0.0084
#    Conductance: 0.2047
#    Normalized Cut: 0.2118
#    Max-ODF: 0.4000
#    Avg-ODF: 0.1756
#    Flake-ODF: 0.0000
#    Modularity: 16.2745
#  Community 7:
#    Internal density: 0.1516
#    Edges inside: 201.0000
#    Average degree: 7.7308
#    FOMD: 0.3462
#    TPR: 0.7308
#    Expansion: 0.1538
#    Cut Ratio: 0.0005
#    Conductance: 0.0195
#    Normalized Cut: 0.0212
#    Max-ODF: 0.3333
#    Avg-ODF: 0.0165
#    Flake-ODF: 0.0000
#    Modularity: 46.0792
#  Community 8:
#    Internal density: 0.8667
#    Edges inside: 39.0000
#    Average degree: 7.8000
#    FOMD: 0.0000
#    TPR: 1.0000
#    Expansion: 0.1000
#    Cut Ratio: 0.0003
#    Conductance: 0.0127
#    Normalized Cut: 0.0129
#    Max-ODF: 0.2500
#    Avg-ODF: 0.0250
#    Flake-ODF: 0.0000
#    Modularity: 9.5952
#  Community 9:
#    Internal density: 1.0000
#    Edges inside: 1.0000
#    Average degree: 1.0000
#    FOMD: 0.0000
#    TPR: 0.0000
#    Expansion: 0.0000
#    Cut Ratio: 0.0000
#    Conductance: 0.0000
#    Normalized Cut: 0.0000
#    Max-ODF: 0.0000
#    Avg-ODF: 0.0000
#    Flake-ODF: 0.0000
#    Modularity: 0.2499
#  Community 10:
#    Internal density: 0.6429
#    Edges inside: 18.0000
#    Average degree: 4.5000
#    FOMD: 0.0000
#    TPR: 0.8750
#    Expansion: 0.2500
#    Cut Ratio: 0.0008
#    Conductance: 0.0526
#    Normalized Cut: 0.0530
#    Max-ODF: 0.1429
#    Avg-ODF: 0.0357
#    Flake-ODF: 0.0000
#    Modularity: 4.4642
#  Community 11:
#    Internal density: 0.6667
#    Edges inside: 2.0000
#    Average degree: 1.3333
#    FOMD: 0.0000
#    TPR: 0.0000
#    Expansion: 0.0000
#    Cut Ratio: 0.0000
#    Conductance: 0.0000
#    Normalized Cut: 0.0000
#    Max-ODF: 0.0000
#    Avg-ODF: 0.0000
#    Flake-ODF: 0.0000
#    Modularity: 0.4996
#  Community 12:
#    Internal density: 1.0000
#    Edges inside: 1.0000
#    Average degree: 1.0000
#    FOMD: 0.0000
#    TPR: 0.0000
#    Expansion: 0.0000
#    Cut Ratio: 0.0000
#    Conductance: 0.0000
#    Normalized Cut: 0.0000
#    Max-ODF: 0.0000
#    Avg-ODF: 0.0000
#    Flake-ODF: 0.0000
#    Modularity: 0.2499
#  Community 13:
#    Internal density: 1.0000
#    Edges inside: 1.0000
#    Average degree: 1.0000
#    FOMD: 0.0000
#    TPR: 0.0000
#    Expansion: 0.0000
#    Cut Ratio: 0.0000
#    Conductance: 0.0000
#    Normalized Cut: 0.0000
#    Max-ODF: 0.0000
#    Avg-ODF: 0.0000
#    Flake-ODF: 0.0000
#    Modularity: 0.2499
# Girvan-Newman communities scoring for node_id=0:
#  Community 0:
#    Internal density: 0.0810
#    Edges inside: 2190.0000
#    Average degree: 18.7983
#    FOMD: 0.5966
#    TPR: 0.9270
#    Expansion: 0.0343
#    Cut Ratio: 0.0003
#    Conductance: 0.0018
#    Normalized Cut: 0.0138
#    Max-ODF: 0.3333
#    Avg-ODF: 0.0043
#    Flake-ODF: 0.0000
#    Modularity: 69.7672
#  Community 1:
#    Internal density: 0.0772
#    Edges inside: 316.0000
#    Average degree: 6.9451
#    FOMD: 0.2527
#    TPR: 0.7582
#    Expansion: 0.0879
#    Cut Ratio: 0.0004
#    Conductance: 0.0125
#    Normalized Cut: 0.0143
#    Max-ODF: 0.5000
#    Avg-ODF: 0.0163
#    Flake-ODF: 0.0000
#    Modularity: 68.8372
#  Community 2:
#    Internal density: 1.0000
#    Edges inside: 1.0000
#    Average degree: 1.0000
#    FOMD: 0.0000
#    TPR: 0.0000
#    Expansion: 0.0000
#    Cut Ratio: 0.0000
#    Conductance: 0.0000
#    Normalized Cut: 0.0000
#    Max-ODF: 0.0000
#    Avg-ODF: 0.0000
#    Flake-ODF: 0.0000
#    Modularity: 0.2499
#  Community 3:
#    Internal density: 0.6667
#    Edges inside: 2.0000
#    Average degree: 1.3333
#    FOMD: 0.0000
#    TPR: 0.0000
#    Expansion: 0.0000
#    Cut Ratio: 0.0000
#    Conductance: 0.0000
#    Normalized Cut: 0.0000
#    Max-ODF: 0.0000
#    Avg-ODF: 0.0000
#    Flake-ODF: 0.0000
#    Modularity: 0.4996
#  Community 4:
#    Internal density: 1.0000
#    Edges inside: 1.0000
#    Average degree: 1.0000
#    FOMD: 0.0000
#    TPR: 0.0000
#    Expansion: 0.0000
#    Cut Ratio: 0.0000
#    Conductance: 0.0000
#    Normalized Cut: 0.0000
#    Max-ODF: 0.0000
#    Avg-ODF: 0.0000
#    Flake-ODF: 0.0000
#    Modularity: 0.2499
#  Community 5:
#    Internal density: 1.0000
#    Edges inside: 1.0000
#    Average degree: 1.0000
#    FOMD: 0.0000
#    TPR: 0.0000
#    Expansion: 0.0000
#    Cut Ratio: 0.0000
#    Conductance: 0.0000
#    Normalized Cut: 0.0000
#    Max-ODF: 0.0000
#    Avg-ODF: 0.0000
#    Flake-ODF: 0.0000
#    Modularity: 0.2499
# 107	0.4365	0.3270	0.0149	0.0917
# Louvain communities scoring for node_id=107:
#  Community 0:
#    Internal density: 0.2957
#    Edges inside: 15473.0000
#    Average degree: 95.5123
#    FOMD: 0.8673
#    TPR: 0.9907
#    Expansion: 2.6605
#    Cut Ratio: 0.0037
#    Conductance: 0.0271
#    Normalized Cut: 0.0639
#    Max-ODF: 0.2353
#    Avg-ODF: 0.0326
#    Flake-ODF: 0.0000
#    Modularity: 1504.2624
#  Community 1:
#    Internal density: 0.1353
#    Edges inside: 1809.0000
#    Average degree: 22.0610
#    FOMD: 0.1707
#    TPR: 0.9634
#    Expansion: 4.6402
#    Cut Ratio: 0.0053
#    Conductance: 0.1738
#    Normalized Cut: 0.1888
#    Max-ODF: 0.7941
#    Avg-ODF: 0.1656
#    Flake-ODF: 0.0793
#    Modularity: 407.4454
#  Community 2:
#    Internal density: 0.1906
#    Edges inside: 1908.0000
#    Average degree: 26.8732
#    FOMD: 0.2887
#    TPR: 0.9859
#    Expansion: 4.3310
#    Cut Ratio: 0.0049
#    Conductance: 0.1388
#    Normalized Cut: 0.1510
#    Max-ODF: 0.6667
#    Avg-ODF: 0.1318
#    Flake-ODF: 0.0282
#    Modularity: 431.1250
#  Community 3:
#    Internal density: 0.2939
#    Edges inside: 4222.0000
#    Average degree: 49.6706
#    FOMD: 0.6941
#    TPR: 0.9824
#    Expansion: 2.9588
#    Cut Ratio: 0.0034
#    Conductance: 0.0562
#    Normalized Cut: 0.0673
#    Max-ODF: 0.5652
#    Avg-ODF: 0.0563
#    Flake-ODF: 0.0118
#    Modularity: 868.4631
#  Community 4:
#    Internal density: 0.0658
#    Edges inside: 1144.0000
#    Average degree: 12.2353
#    FOMD: 0.0053
#    TPR: 0.9198
#    Expansion: 2.8930
#    Cut Ratio: 0.0034
#    Conductance: 0.1912
#    Normalized Cut: 0.2017
#    Max-ODF: 0.8000
#    Avg-ODF: 0.1594
#    Flake-ODF: 0.0802
#    Modularity: 267.3001
#  Community 5:
#    Internal density: 0.7397
#    Edges inside: 520.0000
#    Average degree: 27.3684
#    FOMD: 0.0000
#    TPR: 1.0000
#    Expansion: 0.9474
#    Cut Ratio: 0.0010
#    Conductance: 0.0335
#    Normalized Cut: 0.0341
#    Max-ODF: 0.2222
#    Avg-ODF: 0.0326
#    Flake-ODF: 0.0000
#    Modularity: 127.2948
#  Community 6:
#    Internal density: 0.5333
#    Edges inside: 8.0000
#    Average degree: 2.6667
#    FOMD: 0.0000
#    TPR: 1.0000
#    Expansion: 0.1667
#    Cut Ratio: 0.0002
#    Conductance: 0.0588
#    Normalized Cut: 0.0588
#    Max-ODF: 0.2000
#    Avg-ODF: 0.0333
#    Flake-ODF: 0.0000
#    Modularity: 1.9993
#  Community 7:
#    Internal density: 1.0000
#    Edges inside: 3.0000
#    Average degree: 2.0000
#    FOMD: 0.0000
#    TPR: 1.0000
#    Expansion: 1.6667
#    Cut Ratio: 0.0016
#    Conductance: 0.4545
#    Normalized Cut: 0.4546
#    Max-ODF: 0.6000
#    Avg-ODF: 0.3667
#    Flake-ODF: 0.3333
#    Modularity: 0.7497
# Girvan-Newman communities scoring for node_id=107:
#  Community 0:
#    Internal density: 0.0507
#    Edges inside: 26740.0000
#    Average degree: 52.0233
#    FOMD: 0.4951
#    TPR: 0.9776
#    Expansion: 0.0010
#    Cut Ratio: 0.0002
#    Conductance: 0.0000
#    Normalized Cut: 0.0527
#    Max-ODF: 0.0526
#    Avg-ODF: 0.0001
#    Flake-ODF: 0.0000
#    Modularity: 1.9993
#  Community 1:
#    Internal density: 0.5333
#    Edges inside: 8.0000
#    Average degree: 2.6667
#    FOMD: 0.0000
#    TPR: 1.0000
#    Expansion: 0.1667
#    Cut Ratio: 0.0002
#    Conductance: 0.0588
#    Normalized Cut: 0.0588
#    Max-ODF: 0.2000
#    Avg-ODF: 0.0333
#    Flake-ODF: 0.0000
#    Modularity: 1.9993
# 348	0.2387	0.4681	0.2869	0.3276
# Louvain communities scoring for node_id=348:
#  Community 0:
#    Internal density: 0.5976
#    Edges inside: 398.0000
#    Average degree: 21.5135
#    FOMD: 0.5676
#    TPR: 1.0000
#    Expansion: 27.5135
#    Cut Ratio: 0.1471
#    Conductance: 0.5612
#    Normalized Cut: 0.7153
#    Max-ODF: 0.6585
#    Avg-ODF: 0.5415
#    Flake-ODF: 0.7838
#    Modularity: 35.0695
#  Community 1:
#    Internal density: 0.2385
#    Edges inside: 186.0000
#    Average degree: 9.3000
#    FOMD: 0.0250
#    TPR: 0.9250
#    Expansion: 14.8000
#    Cut Ratio: 0.0804
#    Conductance: 0.6141
#    Normalized Cut: 0.7038
#    Max-ODF: 0.7681
#    Avg-ODF: 0.4600
#    Flake-ODF: 0.4500
#    Modularity: 28.3042
#  Community 2:
#    Internal density: 0.2525
#    Edges inside: 462.0000
#    Average degree: 15.1475
#    FOMD: 0.1967
#    TPR: 1.0000
#    Expansion: 9.1311
#    Cut Ratio: 0.0560
#    Conductance: 0.3761
#    Normalized Cut: 0.4687
#    Max-ODF: 0.7857
#    Avg-ODF: 0.2768
#    Flake-ODF: 0.1639
#    Modularity: 72.5536
#  Community 3:
#    Internal density: 0.5744
#    Edges inside: 448.0000
#    Average degree: 22.4000
#    FOMD: 0.5000
#    TPR: 1.0000
#    Expansion: 19.6500
#    Cut Ratio: 0.1068
#    Conductance: 0.4673
#    Normalized Cut: 0.5926
#    Max-ODF: 0.6932
#    Avg-ODF: 0.4140
#    Flake-ODF: 0.4250
#    Modularity: 56.6052
#  Community 4:
#    Internal density: 0.6632
#    Edges inside: 126.0000
#    Average degree: 12.6000
#    FOMD: 0.0000
#    TPR: 1.0000
#    Expansion: 3.8000
#    Cut Ratio: 0.0186
#    Conductance: 0.2317
#    Normalized Cut: 0.2439
#    Max-ODF: 0.7609
#    Avg-ODF: 0.1719
#    Flake-ODF: 0.0500
#    Modularity: 29.3935
#  Community 5:
#    Internal density: 0.6889
#    Edges inside: 31.0000
#    Average degree: 6.2000
#    FOMD: 0.0000
#    TPR: 1.0000
#    Expansion: 0.1000
#    Cut Ratio: 0.0005
#    Conductance: 0.0159
#    Normalized Cut: 0.0160
#    Max-ODF: 0.1111
#    Avg-ODF: 0.0111
#    Flake-ODF: 0.0000
#    Modularity: 7.6723
#  Community 6:
#    Internal density: 0.1833
#    Edges inside: 22.0000
#    Average degree: 2.7500
#    FOMD: 0.0000
#    TPR: 0.5000
#    Expansion: 0.5000
#    Cut Ratio: 0.0024
#    Conductance: 0.1538
#    Normalized Cut: 0.1551
#    Max-ODF: 0.7500
#    Avg-ODF: 0.1010
#    Flake-ODF: 0.0625
#    Modularity: 5.4471
# Girvan-Newman communities scoring for node_id=348:
#  Community 0:
#    Internal density: 0.1387
#    Edges inside: 3160.0000
#    Average degree: 29.5327
#    FOMD: 0.5187
#    TPR: 0.9533
#    Expansion: 0.0047
#    Cut Ratio: 0.0005
#    Conductance: 0.0002
#    Normalized Cut: 0.0155
#    Max-ODF: 0.1667
#    Avg-ODF: 0.0008
#    Flake-ODF: 0.0000
#    Modularity: 7.6723
#  Community 1:
#    Internal density: 0.6889
#    Edges inside: 31.0000
#    Average degree: 6.2000
#    FOMD: 0.0000
#    TPR: 1.0000
#    Expansion: 0.1000
#    Cut Ratio: 0.0005
#    Conductance: 0.0159
#    Normalized Cut: 0.0160
#    Max-ODF: 0.1111
#    Avg-ODF: 0.0111
#    Flake-ODF: 0.0000
#    Modularity: 7.6723
# 414	0.6581	0.5362	0.3957	0.3912
# Louvain communities scoring for node_id=414:
#  Community 0:
#    Internal density: 0.8667
#    Edges inside: 260.0000
#    Average degree: 20.8000
#    FOMD: 0.4000
#    TPR: 1.0000
#    Expansion: 0.0800
#    Cut Ratio: 0.0006
#    Conductance: 0.0038
#    Normalized Cut: 0.0045
#    Max-ODF: 0.0556
#    Avg-ODF: 0.0041
#    Flake-ODF: 0.0000
#    Modularity: 54.9408
#  Community 1:
#    Internal density: 0.4024
#    Edges inside: 944.0000
#    Average degree: 27.3623
#    FOMD: 0.6812
#    TPR: 1.0000
#    Expansion: 0.7681
#    Cut Ratio: 0.0095
#    Conductance: 0.0273
#    Normalized Cut: 0.0615
#    Max-ODF: 0.2500
#    Avg-ODF: 0.0323
#    Flake-ODF: 0.0000
#    Modularity: 96.9170
#  Community 2:
#    Internal density: 0.3396
#    Edges inside: 433.0000
#    Average degree: 16.9804
#    FOMD: 0.2745
#    TPR: 0.9804
#    Expansion: 0.9020
#    Cut Ratio: 0.0091
#    Conductance: 0.0504
#    Normalized Cut: 0.0684
#    Max-ODF: 0.3846
#    Avg-ODF: 0.0448
#    Flake-ODF: 0.0000
#    Modularity: 77.5447
#  Community 3:
#    Internal density: 0.6667
#    Edges inside: 2.0000
#    Average degree: 1.3333
#    FOMD: 0.0000
#    TPR: 0.0000
#    Expansion: 1.6667
#    Cut Ratio: 0.0113
#    Conductance: 0.5556
#    Normalized Cut: 0.5570
#    Max-ODF: 0.6667
#    Avg-ODF: 0.5556
#    Flake-ODF: 0.3333
#    Modularity: 0.4970
#  Community 4:
#    Internal density: 1.0000
#    Edges inside: 1.0000
#    Average degree: 1.0000
#    FOMD: 0.0000
#    TPR: 0.0000
#    Expansion: 0.0000
#    Cut Ratio: 0.0000
#    Conductance: 0.0000
#    Normalized Cut: 0.0000
#    Max-ODF: 0.0000
#    Avg-ODF: 0.0000
#    Flake-ODF: 0.0000
#    Modularity: 0.2499
# Girvan-Newman communities scoring for node_id=414:
#  Community 0:
#    Internal density: 0.8667
#    Edges inside: 260.0000
#    Average degree: 20.8000
#    FOMD: 0.4000
#    TPR: 1.0000
#    Expansion: 0.0800
#    Cut Ratio: 0.0006
#    Conductance: 0.0038
#    Normalized Cut: 0.0045
#    Max-ODF: 0.0556
#    Avg-ODF: 0.0041
#    Flake-ODF: 0.0000
#    Modularity: 54.9408
#  Community 1:
#    Internal density: 0.1906
#    Edges inside: 1430.0000
#    Average degree: 23.2520
#    FOMD: 0.5041
#    TPR: 0.9837
#    Expansion: 0.0163
#    Cut Ratio: 0.0006
#    Conductance: 0.0007
#    Normalized Cut: 0.0045
#    Max-ODF: 0.0667
#    Avg-ODF: 0.0007
#    Flake-ODF: 0.0000
#    Modularity: 55.1136
#  Community 2:
#    Internal density: 1.0000
#    Edges inside: 1.0000
#    Average degree: 1.0000
#    FOMD: 0.0000
#    TPR: 0.0000
#    Expansion: 0.0000
#    Cut Ratio: 0.0000
#    Conductance: 0.0000
#    Normalized Cut: 0.0000
#    Max-ODF: 0.0000
#    Avg-ODF: 0.0000
#    Flake-ODF: 0.0000
#    Modularity: 0.2499
# 686	0.4002	0.4994	0.0236	0.3243
# Louvain communities scoring for node_id=686:
#  Community 0:
#    Internal density: 0.4228
#    Edges inside: 400.0000
#    Average degree: 18.1818
#    FOMD: 0.6591
#    TPR: 1.0000
#    Expansion: 10.3182
#    Cut Ratio: 0.0832
#    Conductance: 0.3620
#    Normalized Cut: 0.5151
#    Max-ODF: 0.5429
#    Avg-ODF: 0.2952
#    Flake-ODF: 0.1364
#    Modularity: 40.6508
#  Community 1:
#    Internal density: 0.2396
#    Edges inside: 259.0000
#    Average degree: 11.0213
#    FOMD: 0.2979
#    TPR: 0.9574
#    Expansion: 9.6170
#    Cut Ratio: 0.0795
#    Conductance: 0.4660
#    Normalized Cut: 0.6052
#    Max-ODF: 0.6667
#    Avg-ODF: 0.3891
#    Flake-ODF: 0.3404
#    Modularity: 29.2390
#  Community 2:
#    Internal density: 0.3215
#    Edges inside: 226.0000
#    Average degree: 11.8947
#    FOMD: 0.3947
#    TPR: 0.9474
#    Expansion: 8.3947
#    Cut Ratio: 0.0646
#    Conductance: 0.4137
#    Normalized Cut: 0.5141
#    Max-ODF: 0.6818
#    Avg-ODF: 0.3291
#    Flake-ODF: 0.2632
#    Modularity: 34.0649
#  Community 3:
#    Internal density: 0.2621
#    Edges inside: 130.0000
#    Average degree: 8.1250
#    FOMD: 0.0000
#    TPR: 0.9688
#    Expansion: 1.1562
#    Cut Ratio: 0.0085
#    Conductance: 0.1246
#    Normalized Cut: 0.1366
#    Max-ODF: 0.6667
#    Avg-ODF: 0.1153
#    Flake-ODF: 0.0312
#    Modularity: 29.1709
#  Community 4:
#    Internal density: 1.0000
#    Edges inside: 6.0000
#    Average degree: 3.0000
#    FOMD: 0.0000
#    TPR: 1.0000
#    Expansion: 0.7500
#    Cut Ratio: 0.0046
#    Conductance: 0.2000
#    Normalized Cut: 0.2009
#    Max-ODF: 0.5000
#    Avg-ODF: 0.1250
#    Flake-ODF: 0.0000
#    Modularity: 1.4915
#  Community 5:
#    Internal density: 0.6667
#    Edges inside: 2.0000
#    Average degree: 1.3333
#    FOMD: 0.0000
#    TPR: 0.0000
#    Expansion: 0.3333
#    Cut Ratio: 0.0020
#    Conductance: 0.2000
#    Normalized Cut: 0.2003
#    Max-ODF: 0.3333
#    Avg-ODF: 0.1111
#    Flake-ODF: 0.0000
#    Modularity: 0.4991
# Girvan-Newman communities scoring for node_id=686:
#  Community 0:
#    Internal density: 0.1222
#    Edges inside: 1653.0000
#    Average degree: 20.0364
#    FOMD: 0.5030
#    TPR: 0.9697
#    Expansion: 0.0061
#    Cut Ratio: 0.0020
#    Conductance: 0.0003
#    Normalized Cut: 0.1432
#    Max-ODF: 0.0357
#    Avg-ODF: 0.0002
#    Flake-ODF: 0.0000
#    Modularity: 0.4991
#  Community 1:
#    Internal density: 0.6667
#    Edges inside: 2.0000
#    Average degree: 1.3333
#    FOMD: 0.0000
#    TPR: 0.0000
#    Expansion: 0.3333
#    Cut Ratio: 0.0020
#    Conductance: 0.2000
#    Normalized Cut: 0.2003
#    Max-ODF: 0.3333
#    Avg-ODF: 0.1111
#    Flake-ODF: 0.0000
#    Modularity: 0.4991
# 698	0.7003	0.5110	0.5440	0.3884
# Louvain communities scoring for node_id=698:
#  Community 0:
#    Internal density: 0.3939
#    Edges inside: 26.0000
#    Average degree: 4.3333
#    FOMD: 0.0000
#    TPR: 1.0000
#    Expansion: 0.0000
#    Cut Ratio: 0.0000
#    Conductance: 0.0000
#    Normalized Cut: 0.0000
#    Max-ODF: 0.0000
#    Avg-ODF: 0.0000
#    Flake-ODF: 0.0000
#    Modularity: 5.8741
#  Community 1:
#    Internal density: 0.6732
#    Edges inside: 103.0000
#    Average degree: 11.4444
#    FOMD: 0.7778
#    TPR: 1.0000
#    Expansion: 2.0556
#    Cut Ratio: 0.0478
#    Conductance: 0.1523
#    Normalized Cut: 0.2520
#    Max-ODF: 0.2941
#    Avg-ODF: 0.1330
#    Flake-ODF: 0.0000
#    Modularity: 12.0813
#  Community 2:
#    Internal density: 0.5524
#    Edges inside: 58.0000
#    Average degree: 7.7333
#    FOMD: 0.6000
#    TPR: 1.0000
#    Expansion: 1.4000
#    Cut Ratio: 0.0304
#    Conductance: 0.1533
#    Normalized Cut: 0.2005
#    Max-ODF: 0.5862
#    Avg-ODF: 0.0642
#    Flake-ODF: 0.0667
#    Modularity: 10.1553
#  Community 3:
#    Internal density: 0.6667
#    Edges inside: 14.0000
#    Average degree: 4.0000
#    FOMD: 0.0000
#    TPR: 0.8571
#    Expansion: 4.5714
#    Cut Ratio: 0.0847
#    Conductance: 0.5333
#    Normalized Cut: 0.5922
#    Max-ODF: 0.7273
#    Avg-ODF: 0.4088
#    Flake-ODF: 0.2857
#    Modularity: 2.6667
#  Community 4:
#    Internal density: 0.6667
#    Edges inside: 24.0000
#    Average degree: 5.3333
#    FOMD: 0.1111
#    TPR: 0.8889
#    Expansion: 0.0000
#    Cut Ratio: 0.0000
#    Conductance: 0.0000
#    Normalized Cut: 0.0000
#    Max-ODF: 0.0000
#    Avg-ODF: 0.0000
#    Flake-ODF: 0.0000
#    Modularity: 5.4667
# Girvan-Newman communities scoring for node_id=698:
#  Community 0:
#    Internal density: 0.3939
#    Edges inside: 26.0000
#    Average degree: 4.3333
#    FOMD: 0.0000
#    TPR: 1.0000
#    Expansion: 0.0000
#    Cut Ratio: 0.0000
#    Conductance: 0.0000
#    Normalized Cut: 0.0000
#    Max-ODF: 0.0000
#    Avg-ODF: 0.0000
#    Flake-ODF: 0.0000
#    Modularity: 5.8741
#  Community 1:
#    Internal density: 0.3349
#    Edges inside: 211.0000
#    Average degree: 11.7222
#    FOMD: 0.7500
#    TPR: 0.9722
#    Expansion: 0.1111
#    Cut Ratio: 0.0044
#    Conductance: 0.0094
#    Normalized Cut: 0.0422
#    Max-ODF: 0.1034
#    Avg-ODF: 0.0052
#    Flake-ODF: 0.0000
#    Modularity: 10.7417
#  Community 2:
#    Internal density: 0.8333
#    Edges inside: 5.0000
#    Average degree: 2.5000
#    FOMD: 0.0000
#    TPR: 1.0000
#    Expansion: 1.0000
#    Cut Ratio: 0.0175
#    Conductance: 0.2857
#    Normalized Cut: 0.2932
#    Max-ODF: 0.5000
#    Avg-ODF: 0.2708
#    Flake-ODF: 0.0000
#    Modularity: 1.2046
#  Community 3:
#    Internal density: 0.6667
#    Edges inside: 24.0000
#    Average degree: 5.3333
#    FOMD: 0.1111
#    TPR: 0.8889
#    Expansion: 0.0000
#    Cut Ratio: 0.0000
#    Conductance: 0.0000
#    Normalized Cut: 0.0000
#    Max-ODF: 0.0000
#    Avg-ODF: 0.0000
#    Flake-ODF: 0.0000
#    Modularity: 5.4667
# 1684	0.6961	0.4610	0.1471	0.2000
# Louvain communities scoring for node_id=1684:
#  Community 0:
#    Internal density: 0.2575
#    Edges inside: 4148.0000
#    Average degree: 46.0889
#    FOMD: 0.7056
#    TPR: 0.9944
#    Expansion: 6.9556
#    Cut Ratio: 0.0115
#    Conductance: 0.1311
#    Normalized Cut: 0.1907
#    Max-ODF: 0.5263
#    Avg-ODF: 0.1346
#    Flake-ODF: 0.0111
#    Modularity: 630.7130
#  Community 1:
#    Internal density: 0.2849
#    Edges inside: 5278.0000
#    Average degree: 54.6943
#    FOMD: 0.8083
#    TPR: 0.9896
#    Expansion: 1.2332
#    Cut Ratio: 0.0021
#    Conductance: 0.0220
#    Normalized Cut: 0.0355
#    Max-ODF: 0.3333
#    Avg-ODF: 0.0250
#    Flake-ODF: 0.0000
#    Modularity: 800.2543
#  Community 2:
#    Internal density: 0.0602
#    Edges inside: 1654.0000
#    Average degree: 14.0766
#    FOMD: 0.1106
#    TPR: 0.9574
#    Expansion: 5.2128
#    Cut Ratio: 0.0095
#    Conductance: 0.2702
#    Normalized Cut: 0.3174
#    Max-ODF: 0.6667
#    Avg-ODF: 0.2324
#    Flake-ODF: 0.0681
#    Modularity: 321.9244
#  Community 3:
#    Internal density: 0.2274
#    Edges inside: 774.0000
#    Average degree: 18.6506
#    FOMD: 0.2169
#    TPR: 0.9880
#    Expansion: 7.8072
#    Cut Ratio: 0.0111
#    Conductance: 0.2951
#    Normalized Cut: 0.3190
#    Max-ODF: 0.6923
#    Avg-ODF: 0.2512
#    Flake-ODF: 0.1566
#    Modularity: 172.0082
#  Community 4:
#    Internal density: 0.2860
#    Edges inside: 151.0000
#    Average degree: 9.1515
#    FOMD: 0.0000
#    TPR: 0.9697
#    Expansion: 5.2121
#    Cut Ratio: 0.0069
#    Conductance: 0.3629
#    Normalized Cut: 0.3690
#    Max-ODF: 0.6333
#    Avg-ODF: 0.3064
#    Flake-ODF: 0.1212
#    Modularity: 36.7487
#  Community 5:
#    Internal density: 0.9333
#    Edges inside: 14.0000
#    Average degree: 4.6667
#    FOMD: 0.0000
#    TPR: 1.0000
#    Expansion: 0.0000
#    Cut Ratio: 0.0000
#    Conductance: 0.0000
#    Normalized Cut: 0.0000
#    Max-ODF: 0.0000
#    Avg-ODF: 0.0000
#    Flake-ODF: 0.0000
#    Modularity: 3.4965
#  Community 6:
#    Internal density: 0.7953
#    Edges inside: 136.0000
#    Average degree: 14.3158
#    FOMD: 0.0000
#    TPR: 1.0000
#    Expansion: 0.3684
#    Cut Ratio: 0.0005
#    Conductance: 0.0251
#    Normalized Cut: 0.0253
#    Max-ODF: 0.1667
#    Avg-ODF: 0.0241
#    Flake-ODF: 0.0000
#    Modularity: 33.6531
#  Community 7:
#    Internal density: 0.3004
#    Edges inside: 76.0000
#    Average degree: 6.6087
#    FOMD: 0.0000
#    TPR: 0.8696
#    Expansion: 0.1304
#    Cut Ratio: 0.0002
#    Conductance: 0.0194
#    Normalized Cut: 0.0195
#    Max-ODF: 0.5000
#    Avg-ODF: 0.0329
#    Flake-ODF: 0.0000
#    Modularity: 18.8929
#  Community 8:
#    Internal density: 0.3889
#    Edges inside: 14.0000
#    Average degree: 3.1111
#    FOMD: 0.0000
#    TPR: 0.6667
#    Expansion: 0.5556
#    Cut Ratio: 0.0007
#    Conductance: 0.1515
#    Normalized Cut: 0.1517
#    Max-ODF: 0.2500
#    Avg-ODF: 0.0802
#    Flake-ODF: 0.0000
#    Modularity: 3.4951
#  Community 9:
#    Internal density: 1.0000
#    Edges inside: 3.0000
#    Average degree: 2.0000
#    FOMD: 0.0000
#    TPR: 1.0000
#    Expansion: 0.0000
#    Cut Ratio: 0.0000
#    Conductance: 0.0000
#    Normalized Cut: 0.0000
#    Max-ODF: 0.0000
#    Avg-ODF: 0.0000
#    Flake-ODF: 0.0000
#    Modularity: 0.7498
#  Community 10:
#    Internal density: 1.0000
#    Edges inside: 1.0000
#    Average degree: 1.0000
#    FOMD: 0.0000
#    TPR: 0.0000
#    Expansion: 0.0000
#    Cut Ratio: 0.0000
#    Conductance: 0.0000
#    Normalized Cut: 0.0000
#    Max-ODF: 0.0000
#    Avg-ODF: 0.0000
#    Flake-ODF: 0.0000
#    Modularity: 0.2500
# Girvan-Newman communities scoring for node_id=1684:
#  Community 0:
#    Internal density: 0.0493
#    Edges inside: 13927.0000
#    Average degree: 37.0399
#    FOMD: 0.5173
#    TPR: 0.9814
#    Expansion: 0.0040
#    Cut Ratio: 0.0001
#    Conductance: 0.0001
#    Normalized Cut: 0.0153
#    Max-ODF: 0.1429
#    Avg-ODF: 0.0003
#    Flake-ODF: 0.0000
#    Modularity: 23.3374
#  Community 1:
#    Internal density: 0.9333
#    Edges inside: 14.0000
#    Average degree: 4.6667
#    FOMD: 0.0000
#    TPR: 1.0000
#    Expansion: 0.0000
#    Cut Ratio: 0.0000
#    Conductance: 0.0000
#    Normalized Cut: 0.0000
#    Max-ODF: 0.0000
#    Avg-ODF: 0.0000
#    Flake-ODF: 0.0000
#    Modularity: 3.4965
#  Community 2:
#    Internal density: 0.3004
#    Edges inside: 76.0000
#    Average degree: 6.6087
#    FOMD: 0.0000
#    TPR: 0.8696
#    Expansion: 0.1304
#    Cut Ratio: 0.0002
#    Conductance: 0.0194
#    Normalized Cut: 0.0195
#    Max-ODF: 0.5000
#    Avg-ODF: 0.0329
#    Flake-ODF: 0.0000
#    Modularity: 18.8929
#  Community 3:
#    Internal density: 1.0000
#    Edges inside: 3.0000
#    Average degree: 2.0000
#    FOMD: 0.0000
#    TPR: 1.0000
#    Expansion: 0.0000
#    Cut Ratio: 0.0000
#    Conductance: 0.0000
#    Normalized Cut: 0.0000
#    Max-ODF: 0.0000
#    Avg-ODF: 0.0000
#    Flake-ODF: 0.0000
#    Modularity: 0.7498
#  Community 4:
#    Internal density: 1.0000
#    Edges inside: 1.0000
#    Average degree: 1.0000
#    FOMD: 0.0000
#    TPR: 0.0000
#    Expansion: 0.0000
#    Cut Ratio: 0.0000
#    Conductance: 0.0000
#    Normalized Cut: 0.0000
#    Max-ODF: 0.0000
#    Avg-ODF: 0.0000
#    Flake-ODF: 0.0000
#    Modularity: 0.2500
# 1912	0.4903	0.1728	0.0414	0.0998
# Louvain communities scoring for node_id=1912:
#  Community 0:
#    Internal density: 0.5955
#    Edges inside: 16372.0000
#    Average degree: 139.3362
#    FOMD: 0.8851
#    TPR: 0.9957
#    Expansion: 2.9617
#    Cut Ratio: 0.0058
#    Conductance: 0.0208
#    Normalized Cut: 0.0457
#    Max-ODF: 0.3862
#    Avg-ODF: 0.0254
#    Flake-ODF: 0.0000
#    Modularity: 1765.2864
#  Community 1:
#    Internal density: 0.5654
#    Edges inside: 1486.0000
#    Average degree: 40.7123
#    FOMD: 0.0685
#    TPR: 1.0000
#    Expansion: 2.4110
#    Cut Ratio: 0.0036
#    Conductance: 0.0559
#    Normalized Cut: 0.0590
#    Max-ODF: 0.2969
#    Avg-ODF: 0.0493
#    Flake-ODF: 0.0000
#    Modularity: 350.8716
#  Community 2:
#    Internal density: 0.2670
#    Edges inside: 9915.0000
#    Average degree: 72.6374
#    FOMD: 0.5678
#    TPR: 1.0000
#    Expansion: 3.7729
#    Cut Ratio: 0.0080
#    Conductance: 0.0494
#    Normalized Cut: 0.0743
#    Max-ODF: 0.5392
#    Avg-ODF: 0.0465
#    Flake-ODF: 0.0037
#    Modularity: 1572.9640
#  Community 3:
#    Internal density: 0.5072
#    Edges inside: 140.0000
#    Average degree: 11.6667
#    FOMD: 0.0000
#    TPR: 1.0000
#    Expansion: 2.5000
#    Cut Ratio: 0.0035
#    Conductance: 0.1765
#    Normalized Cut: 0.1775
#    Max-ODF: 0.7778
#    Avg-ODF: 0.1399
#    Flake-ODF: 0.0833
#    Modularity: 34.7594
#  Community 4:
#    Internal density: 0.1076
#    Edges inside: 1032.0000
#    Average degree: 14.8489
#    FOMD: 0.0072
#    TPR: 0.9640
#    Expansion: 1.3957
#    Cut Ratio: 0.0023
#    Conductance: 0.0859
#    Normalized Cut: 0.0893
#    Max-ODF: 0.6000
#    Avg-ODF: 0.0677
#    Flake-ODF: 0.0144
#    Modularity: 247.3868
#  Community 5:
#    Internal density: 0.6667
#    Edges inside: 2.0000
#    Average degree: 1.3333
#    FOMD: 0.0000
#    TPR: 0.0000
#    Expansion: 0.0000
#    Cut Ratio: 0.0000
#    Conductance: 0.0000
#    Normalized Cut: 0.0000
#    Max-ODF: 0.0000
#    Avg-ODF: 0.0000
#    Flake-ODF: 0.0000
#    Modularity: 0.5000
# Girvan-Newman communities scoring for node_id=1912:
#  Community 0:
#    Internal density: 0.1118
#    Edges inside: 29983.0000
#    Average degree: 81.8090
#    FOMD: 0.5089
#    TPR: 0.9945
#    Expansion: 0.0136
#    Cut Ratio: 0.0010
#    Conductance: 0.0002
#    Normalized Cut: 0.1065
#    Max-ODF: 0.1500
#    Avg-ODF: 0.0007
#    Flake-ODF: 0.0000
#    Modularity: 7.9886
#  Community 1:
#    Internal density: 0.5455
#    Edges inside: 30.0000
#    Average degree: 5.4545
#    FOMD: 0.0000
#    TPR: 0.8182
#    Expansion: 0.9091
#    Cut Ratio: 0.0012
#    Conductance: 0.1429
#    Normalized Cut: 0.1430
#    Max-ODF: 0.7500
#    Avg-ODF: 0.1499
#    Flake-ODF: 0.0909
#    Modularity: 7.4898
#  Community 2:
#    Internal density: 0.6667
#    Edges inside: 2.0000
#    Average degree: 1.3333
#    FOMD: 0.0000
#    TPR: 0.0000
#    Expansion: 0.0000
#    Cut Ratio: 0.0000
#    Conductance: 0.0000
#    Normalized Cut: 0.0000
#    Max-ODF: 0.0000
#    Avg-ODF: 0.0000
#    Flake-ODF: 0.0000
#    Modularity: 0.5000
# 3437	0.4985	0.1054	0.0560	0.0306
# Louvain communities scoring for node_id=3437:
#  Community 0:
#    Internal density: 0.1356
#    Edges inside: 1263.0000
#    Average degree: 18.4380
#    FOMD: 0.6058
#    TPR: 0.9635
#    Expansion: 0.5547
#    Cut Ratio: 0.0014
#    Conductance: 0.0292
#    Normalized Cut: 0.0398
#    Max-ODF: 0.5000
#    Avg-ODF: 0.0443
#    Flake-ODF: 0.0000
#    Modularity: 227.8318
#  Community 1:
#    Internal density: 0.2759
#    Edges inside: 112.0000
#    Average degree: 7.7241
#    FOMD: 0.0690
#    TPR: 0.9655
#    Expansion: 0.2069
#    Cut Ratio: 0.0004
#    Conductance: 0.0261
#    Normalized Cut: 0.0267
#    Max-ODF: 0.3333
#    Avg-ODF: 0.0288
#    Flake-ODF: 0.0000
#    Modularity: 27.3131
#  Community 2:
#    Internal density: 0.1370
#    Edges inside: 1028.0000
#    Average degree: 16.7154
#    FOMD: 0.4146
#    TPR: 0.9593
#    Expansion: 3.7886
#    Cut Ratio: 0.0092
#    Conductance: 0.1848
#    Normalized Cut: 0.2428
#    Max-ODF: 0.5000
#    Avg-ODF: 0.1467
#    Flake-ODF: 0.0000
#    Modularity: 174.4049
#  Community 3:
#    Internal density: 0.3523
#    Edges inside: 779.0000
#    Average degree: 23.2537
#    FOMD: 0.7463
#    TPR: 0.9552
#    Expansion: 6.1493
#    Cut Ratio: 0.0132
#    Conductance: 0.2091
#    Normalized Cut: 0.2577
#    Max-ODF: 0.5000
#    Avg-ODF: 0.1741
#    Flake-ODF: 0.0000
#    Modularity: 144.3539
#  Community 4:
#    Internal density: 0.3052
#    Edges inside: 470.0000
#    Average degree: 16.7857
#    FOMD: 0.5179
#    TPR: 0.9464
#    Expansion: 1.5000
#    Cut Ratio: 0.0031
#    Conductance: 0.0820
#    Normalized Cut: 0.0916
#    Max-ODF: 0.5135
#    Avg-ODF: 0.0692
#    Flake-ODF: 0.0179
#    Modularity: 103.8835
#  Community 5:
#    Internal density: 0.5541
#    Edges inside: 128.0000
#    Average degree: 11.6364
#    FOMD: 0.4091
#    TPR: 0.9091
#    Expansion: 1.4545
#    Cut Ratio: 0.0028
#    Conductance: 0.1111
#    Normalized Cut: 0.1145
#    Max-ODF: 0.2857
#    Avg-ODF: 0.1055
#    Flake-ODF: 0.0000
#    Modularity: 30.9229
#  Community 6:
#    Internal density: 0.2242
#    Edges inside: 193.0000
#    Average degree: 9.1905
#    FOMD: 0.2619
#    TPR: 0.9286
#    Expansion: 0.4762
#    Cut Ratio: 0.0010
#    Conductance: 0.0493
#    Normalized Cut: 0.0514
#    Max-ODF: 0.4000
#    Avg-ODF: 0.0331
#    Flake-ODF: 0.0000
#    Modularity: 46.1095
#  Community 7:
#    Internal density: 0.5263
#    Edges inside: 100.0000
#    Average degree: 10.0000
#    FOMD: 0.0000
#    TPR: 1.0000
#    Expansion: 0.9500
#    Cut Ratio: 0.0018
#    Conductance: 0.0868
#    Normalized Cut: 0.0888
#    Max-ODF: 0.1667
#    Avg-ODF: 0.0987
#    Flake-ODF: 0.0000
#    Modularity: 24.3772
#  Community 8:
#    Internal density: 0.7485
#    Edges inside: 128.0000
#    Average degree: 13.4737
#    FOMD: 0.3158
#    TPR: 1.0000
#    Expansion: 0.2632
#    Cut Ratio: 0.0005
#    Conductance: 0.0192
#    Normalized Cut: 0.0197
#    Max-ODF: 0.1818
#    Avg-ODF: 0.0123
#    Flake-ODF: 0.0000
#    Modularity: 31.1154
#  Community 9:
#    Internal density: 0.2794
#    Edges inside: 38.0000
#    Average degree: 4.4706
#    FOMD: 0.0000
#    TPR: 0.9412
#    Expansion: 1.5294
#    Cut Ratio: 0.0030
#    Conductance: 0.2549
#    Normalized Cut: 0.2576
#    Max-ODF: 0.6667
#    Avg-ODF: 0.2034
#    Flake-ODF: 0.1765
#    Modularity: 9.3649
#  Community 10:
#    Internal density: 1.0000
#    Edges inside: 1.0000
#    Average degree: 1.0000
#    FOMD: 0.0000
#    TPR: 0.0000
#    Expansion: 0.0000
#    Cut Ratio: 0.0000
#    Conductance: 0.0000
#    Normalized Cut: 0.0000
#    Max-ODF: 0.0000
#    Avg-ODF: 0.0000
#    Flake-ODF: 0.0000
#    Modularity: 0.2499
# Girvan-Newman communities scoring for node_id=3437:
#  Community 0:
#    Internal density: 0.0356
#    Edges inside: 4679.0000
#    Average degree: 18.2417
#    FOMD: 0.4932
#    TPR: 0.9591
#    Expansion: 0.0097
#    Cut Ratio: 0.0005
#    Conductance: 0.0005
#    Normalized Cut: 0.0188
#    Max-ODF: 0.2000
#    Avg-ODF: 0.0008
#    Flake-ODF: 0.0000
#    Modularity: 31.3518
#  Community 1:
#    Internal density: 0.7485
#    Edges inside: 128.0000
#    Average degree: 13.4737
#    FOMD: 0.3158
#    TPR: 1.0000
#    Expansion: 0.2632
#    Cut Ratio: 0.0005
#    Conductance: 0.0192
#    Normalized Cut: 0.0197
#    Max-ODF: 0.1818
#    Avg-ODF: 0.0123
#    Flake-ODF: 0.0000
#    Modularity: 31.1154
#  Community 2:
#    Internal density: 1.0000
#    Edges inside: 1.0000
#    Average degree: 1.0000
#    FOMD: 0.0000
#    TPR: 0.0000
#    Expansion: 0.0000
#    Cut Ratio: 0.0000
#    Conductance: 0.0000
#    Normalized Cut: 0.0000
#    Max-ODF: 0.0000
#    Avg-ODF: 0.0000
#    Flake-ODF: 0.0000
#    Modularity: 0.2499
# 3980	0.6196	0.4049	0.4384	0.3295
# Louvain communities scoring for node_id=3980:
#  Community 0:
#    Internal density: 0.2667
#    Edges inside: 28.0000
#    Average degree: 3.7333
#    FOMD: 0.2000
#    TPR: 0.6667
#    Expansion: 0.9333
#    Cut Ratio: 0.0252
#    Conductance: 0.2000
#    Normalized Cut: 0.2560
#    Max-ODF: 0.5556
#    Avg-ODF: 0.1372
#    Flake-ODF: 0.0667
#    Modularity: 4.9024
#  Community 1:
#    Internal density: 0.3750
#    Edges inside: 45.0000
#    Average degree: 5.6250
#    FOMD: 0.6250
#    TPR: 0.9375
#    Expansion: 1.6250
#    Cut Ratio: 0.0451
#    Conductance: 0.2241
#    Normalized Cut: 0.3382
#    Max-ODF: 0.5000
#    Avg-ODF: 0.1589
#    Flake-ODF: 0.0000
#    Modularity: 5.4897
#  Community 2:
#    Internal density: 0.4103
#    Edges inside: 32.0000
#    Average degree: 4.9231
#    FOMD: 0.4615
#    TPR: 0.8462
#    Expansion: 2.0000
#    Cut Ratio: 0.0513
#    Conductance: 0.2889
#    Normalized Cut: 0.3913
#    Max-ODF: 0.5294
#    Avg-ODF: 0.2009
#    Flake-ODF: 0.0769
#    Modularity: 4.5325
#  Community 3:
#    Internal density: 1.0000
#    Edges inside: 1.0000
#    Average degree: 1.0000
#    FOMD: 0.0000
#    TPR: 0.0000
#    Expansion: 0.0000
#    Cut Ratio: 0.0000
#    Conductance: 0.0000
#    Normalized Cut: 0.0000
#    Max-ODF: 0.0000
#    Avg-ODF: 0.0000
#    Flake-ODF: 0.0000
#    Modularity: 0.2483
#  Community 4:
#    Internal density: 1.0000
#    Edges inside: 6.0000
#    Average degree: 3.0000
#    FOMD: 0.0000
#    TPR: 1.0000
#    Expansion: 0.0000
#    Cut Ratio: 0.0000
#    Conductance: 0.0000
#    Normalized Cut: 0.0000
#    Max-ODF: 0.0000
#    Avg-ODF: 0.0000
#    Flake-ODF: 0.0000
#    Modularity: 1.4384
#  Community 5:
#    Internal density: 1.0000
#    Edges inside: 1.0000
#    Average degree: 1.0000
#    FOMD: 0.0000
#    TPR: 0.0000
#    Expansion: 0.0000
#    Cut Ratio: 0.0000
#    Conductance: 0.0000
#    Normalized Cut: 0.0000
#    Max-ODF: 0.0000
#    Avg-ODF: 0.0000
#    Flake-ODF: 0.0000
#    Modularity: 0.2483
# Girvan-Newman communities scoring for node_id=3980:
#  Community 0:
#    Internal density: 0.1634
#    Edges inside: 134.0000
#    Average degree: 6.5366
#    FOMD: 0.5854
#    TPR: 0.8293
#    Expansion: 0.0488
#    Cut Ratio: 0.0044
#    Conductance: 0.0074
#    Normalized Cut: 0.0843
#    Max-ODF: 0.1538
#    Avg-ODF: 0.0038
#    Flake-ODF: 0.0000
#    Modularity: 2.2928
#  Community 1:
#    Internal density: 0.6667
#    Edges inside: 2.0000
#    Average degree: 1.3333
#    FOMD: 0.0000
#    TPR: 0.0000
#    Expansion: 0.6667
#    Cut Ratio: 0.0136
#    Conductance: 0.3333
#    Normalized Cut: 0.3402
#    Max-ODF: 0.5000
#    Avg-ODF: 0.2778
#    Flake-ODF: 0.0000
#    Modularity: 0.4846
#  Community 2:
#    Internal density: 1.0000
#    Edges inside: 1.0000
#    Average degree: 1.0000
#    FOMD: 0.0000
#    TPR: 0.0000
#    Expansion: 0.0000
#    Cut Ratio: 0.0000
#    Conductance: 0.0000
#    Normalized Cut: 0.0000
#    Max-ODF: 0.0000
#    Avg-ODF: 0.0000
#    Flake-ODF: 0.0000
#    Modularity: 0.2483
#  Community 3:
#    Internal density: 1.0000
#    Edges inside: 6.0000
#    Average degree: 3.0000
#    FOMD: 0.0000
#    TPR: 1.0000
#    Expansion: 0.0000
#    Cut Ratio: 0.0000
#    Conductance: 0.0000
#    Normalized Cut: 0.0000
#    Max-ODF: 0.0000
#    Avg-ODF: 0.0000
#    Flake-ODF: 0.0000
#    Modularity: 1.4384
#  Community 4:
#    Internal density: 1.0000
#    Edges inside: 1.0000
#    Average degree: 1.0000
#    FOMD: 0.0000
#    TPR: 0.0000
#    Expansion: 0.0000
#    Cut Ratio: 0.0000
#    Conductance: 0.0000
#    Normalized Cut: 0.0000
#    Max-ODF: 0.0000
#    Avg-ODF: 0.0000
#    Flake-ODF: 0.0000
#    Modularity: 0.2483
